# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-be14f654-8ca3-4961-a049-abbe02082720" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-be14f654-8ca3-4961-a049-abbe02082720">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-f832e56c-4beb-47a3-a7e1-17ed93478159" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f832e56c-4beb-47a3-a7e1-17ed93478159">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import numpy as np
import pandas as pd


df = pd.read_csv("train.csv")
df1 = pd.read_csv("test.csv")

# %%
df1 = pd.read_csv("test.csv")
df1
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1     1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2     1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3     1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4     1465         120       RL         43.0     5005   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1454  2915         160       RM         21.0     1936   Pave   NaN      Reg
# 1455  2916         160       RM         21.0     1894   Pave   NaN      Reg
# 1456  2917          20       RL        160.0    20000   Pave   NaN      Reg
# 1457  2918          85       RL         62.0    10441   Pave   NaN      Reg
# 1458  2919          60       RL         74.0     9627   Pave   NaN      Reg
#
# ...

# %%
pd.set_option('display.max_columns', None)



print(df.describe())
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726
# std       1.112799    30.202904     20.645407   181.066207   456.098091
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
print(df.columns)
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
df.drop(columns=['Alley', 'PoolQC', 'MiscFeature'], inplace=True)

# %%
df1.drop(columns=['Alley', 'PoolQC', 'MiscFeature'], inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#corr = df.corr(numeric_only=True)

#selected_features = corr['SalePrice'].abs()

#selected_features = selected_features[selected_features < 0.3].index

#df =  df.drop(columns= selected_features)

# %%
#df1 = df1.drop(columns=selected_features)

# %%
df.shape
df1.shape
# Out:
# (1459, 77)

# %%
#print(set(selected_features) - set(df1.columns))
# Out:
# {'ScreenPorch', '3SsnPorch', 'BsmtHalfBath', 'OverallCond', 'BedroomAbvGr', 'BsmtUnfSF', 'YrSold', 'KitchenAbvGr', 'EnclosedPorch', 'HalfBath', 'Id', 'BsmtFullBath', 'BsmtFinSF2', 'MiscVal', 'LowQualFinSF', 'PoolArea', 'MoSold', 'MSSubClass', 'LotArea'}

# %%
df1
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 0     1461          20       RH         80.0    11622   Pave      Reg
# 1     1462          20       RL         81.0    14267   Pave      IR1
# 2     1463          60       RL         74.0    13830   Pave      IR1
# 3     1464          60       RL         78.0     9978   Pave      IR1
# 4     1465         120       RL         43.0     5005   Pave      IR1
# ...    ...         ...      ...          ...      ...    ...      ...
# 1454  2915         160       RM         21.0     1936   Pave      Reg
# 1455  2916         160       RM         21.0     1894   Pave      Reg
# 1456  2917          20       RL        160.0    20000   Pave      Reg
# 1457  2918          85       RL         62.0    10441   Pave      Reg
# 1458  2919          60       RL         74.0     9627   Pave      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# ...

# %%
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 0        1          60       RL         65.0     8450   Pave      Reg
# 1        2          20       RL         80.0     9600   Pave      Reg
# 2        3          60       RL         68.0    11250   Pave      IR1
# 3        4          70       RL         60.0     9550   Pave      IR1
# 4        5          60       RL         84.0    14260   Pave      IR1
# ...    ...         ...      ...          ...      ...    ...      ...
# 1455  1456          60       RL         62.0     7917   Pave      Reg
# 1456  1457          20       RL         85.0    13175   Pave      Reg
# 1457  1458          70       RL         66.0     9042   Pave      Reg
# 1458  1459          20       RL         68.0     9717   Pave      Reg
# 1459  1460          20       RL         75.0     9937   Pave      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# ...

# %%
df['YearBuilt'].describe()
# Out:
# count    1460.000000
# mean     1971.267808
# std        30.202904
# min      1872.000000
# 25%      1954.000000
# 50%      1973.000000
# 75%      2000.000000
# max      2010.000000
# Name: YearBuilt, dtype: float64

# %%
df['YearRemodAdd'].describe()
# Out:
# count    1460.000000
# mean     1984.865753
# std        20.645407
# min      1950.000000
# 25%      1967.000000
# 50%      1994.000000
# 75%      2004.000000
# max      2010.000000
# Name: YearRemodAdd, dtype: float64

# %%
df['MasVnrArea'].describe()
# Out:
# count    1452.000000
# mean      103.685262
# std       181.066207
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%       166.000000
# max      1600.000000
# Name: MasVnrArea, dtype: float64

# %%
df['TotalBsmtSF'].describe()
# Out:
# count    1460.000000
# mean     1057.429452
# std       438.705324
# min         0.000000
# 25%       795.750000
# 50%       991.500000
# 75%      1298.250000
# max      6110.000000
# Name: TotalBsmtSF, dtype: float64

# %%
df['2ndFlrSF'].describe()
# Out:
# count    1460.000000
# mean      346.992466
# std       436.528436
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%       728.000000
# max      2065.000000
# Name: 2ndFlrSF, dtype: float64

# %%
df['WoodDeckSF'].describe()
# Out:
# count    1460.000000
# mean       94.244521
# std       125.338794
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%       168.000000
# max       857.000000
# Name: WoodDeckSF, dtype: float64

# %%
df['OpenPorchSF'].describe()
# Out:
# count    1460.000000
# mean       46.660274
# std        66.256028
# min         0.000000
# 25%         0.000000
# 50%        25.000000
# 75%        68.000000
# max       547.000000
# Name: OpenPorchSF, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
for feature in df.select_dtypes(include=['int64','float64']).columns:
    plt.figure(figsize=(5, 3))
    plt.boxplot(df[feature])
    plt.title(feature)
    plt.show()

# %%
numeric_cols = df.select_dtypes(include='number').columns

for col in numeric_cols:
    if col == 'SalePrice':   # Skip target (optional)
        continue

    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1

    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR

    df[col] = df[col].clip(lower, upper)

# %%
numeric_cols = df1.select_dtypes(include='number').columns

for col in numeric_cols:
    if col == 'SalePrice':   # Skip target (optional)
        continue

    Q1 = df1[col].quantile(0.25)
    Q3 = df1[col].quantile(0.75)
    IQR = Q3 - Q1

    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR

    df1[col] = df1[col].clip(lower, upper)

# %%
df.shape
# Out:
# (1460, 78)

# %%
df['BsmtFinSF1'].describe()
# Out:
# count    1451.000000
# mean      445.822881
# std       456.543736
# min         0.000000
# 25%         0.000000
# 50%       385.000000
# 75%       715.000000
# max      5644.000000
# Name: BsmtFinSF1, dtype: float64

# %%
numeric_cols = df.select_dtypes(include='number').columns

print(df[numeric_cols].skew().sort_values(ascending=False))
# Out:
# SalePrice        1.882876
# MasVnrArea       1.290554
# OpenPorchSF      1.136301
# WoodDeckSF       1.083673
# MSSubClass       1.019624
# 2ndFlrSF         0.800109
# BsmtUnfSF        0.796931
# BsmtFinSF1       0.739877
# HalfBath         0.675897
# 1stFlrSF         0.664134
# GrLivArea        0.593556
# Fireplaces       0.584655
# OverallCond      0.579334
# BsmtFullBath     0.563057
# TotRmsAbvGrd     0.366919
# OverallQual      0.249513
# TotalBsmtSF      0.237240
# MoSold           0.212053
# LotArea          0.208492
# YrSold           0.096269
# LotFrontage      0.090295
# FullBath         0.036562
# Id               0.000000
# ScreenPorch      0.000000
# PoolArea         0.000000
# BsmtHalfBath     0.000000
# LowQualFinSF     0.000000
# BsmtFinSF2       0.000000
# 3SsnPorch        0.000000
# KitchenAbvGr     0.000000
# MiscVal          0.000000
# EnclosedPorch    0.000000
# GarageArea      -0.069685
# BedroomAbvGr    -0.253298
# GarageCars      -0.391629
# ...

# %%
cols = [
    'SalePrice',
    'MasVnrArea',
    'OpenPorchSF',
    'WoodDeckSF',
    '2ndFlrSF',
    'BsmtUnfSF'
]

for col in cols:
    df[col] = np.log1p(df[col])

print(df[cols].skew().sort_values(ascending=False))
# Out:
# MasVnrArea     0.472277
# 2ndFlrSF       0.289583
# WoodDeckSF     0.148570
# SalePrice      0.121347
# OpenPorchSF   -0.052585
# BsmtUnfSF     -2.193287
# dtype: float64

# %%
cols = [

    'MasVnrArea',
    'OpenPorchSF',
    'WoodDeckSF',
    '2ndFlrSF',
    'BsmtUnfSF'
]

for col in cols:
    df1[col] = np.log1p(df1[col])

print(df1[cols].skew().sort_values(ascending=False))
# Out:
# MasVnrArea     0.533308
# 2ndFlrSF       0.320895
# WoodDeckSF     0.156859
# OpenPorchSF   -0.092218
# BsmtUnfSF     -2.140463
# dtype: float64

# %%
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 0        1          60       RL         65.0   8450.0   Pave      Reg
# 1        2          20       RL         80.0   9600.0   Pave      Reg
# 2        3          60       RL         68.0  11250.0   Pave      IR1
# 3        4          70       RL         60.0   9550.0   Pave      IR1
# 4        5          60       RL         84.0  14260.0   Pave      IR1
# ...    ...         ...      ...          ...      ...    ...      ...
# 1455  1456          60       RL         62.0   7917.0   Pave      Reg
# 1456  1457          20       RL         85.0  13175.0   Pave      Reg
# 1457  1458          70       RL         66.0   9042.0   Pave      Reg
# 1458  1459          20       RL         68.0   9717.0   Pave      Reg
# 1459  1460          20       RL         75.0   9937.0   Pave      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# ...

# %%
for cols in df1.select_dtypes(include=['int64','float64']).columns:
  plt.figure(figsize=(5, 3))
  sns.boxplot(df1[cols])
  plt.show()

# %%
df1
# Out:
#           Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 0     1461.0          20       RH         80.0  11622.0   Pave      Reg
# 1     1462.0          20       RL         81.0  14267.0   Pave      IR1
# 2     1463.0          60       RL         74.0  13830.0   Pave      IR1
# 3     1464.0          60       RL         78.0   9978.0   Pave      IR1
# 4     1465.0         120       RL         43.0   5005.0   Pave      IR1
# ...      ...         ...      ...          ...      ...    ...      ...
# 1454  2189.5         145       RM         27.5   1936.0   Pave      Reg
# 1455  2189.5         145       RM         27.5   1894.0   Pave      Reg
# 1456  2189.5          20       RL        111.5  17673.5   Pave      Reg
# 1457  2189.5          85       RL         62.0  10441.0   Pave      Reg
# 1458  2189.5          60       RL         74.0   9627.0   Pave      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# ...

# %%
for col in df.select_dtypes(include='object').columns:
    print(f"\n{col}")
    print(df[col].value_counts())
# Out:
# MSZoning
# MSZoning
# RL         1151
# RM          218
# FV           65
# RH           16
# C (all)      10
# Name: count, dtype: int64
#
# Street
# Street
# Pave    1454
# Grvl       6
# Name: count, dtype: int64
#
# LotShape
# LotShape
# Reg    925
# IR1    484
# IR2     41
# IR3     10
# Name: count, dtype: int64
#
# LandContour
# LandContour
# Lvl    1311
# Bnk      63
# HLS      50
# Low      36
# Name: count, dtype: int64
#
# Utilities
# Utilities
# AllPub    1459
# NoSeWa       1
# Name: count, dtype: int64
#
# LotConfig
# LotConfig
# Inside     1052
# Corner      263
# CulDSac      94
# FR2          47
# FR3           4
# Name: count, dtype: int64
#
# LandSlope
# LandSlope
# Gtl    1382
# Mod      65
# Sev      13
# Name: count, dtype: int64
#
# Neighborhood
# Neighborhood
# NAmes      225
# CollgCr    150
# OldTown    113
# Edwards    100
# Somerst     86
# Gilbert     79
# NridgHt     77
# Sawyer      74
# NWAmes      73
# SawyerW     59
# BrkSide     58
# Crawfor     51
# ...

# %%
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 0        1          60       RL         65.0   8450.0   Pave      Reg
# 1        2          20       RL         80.0   9600.0   Pave      Reg
# 2        3          60       RL         68.0  11250.0   Pave      IR1
# 3        4          70       RL         60.0   9550.0   Pave      IR1
# 4        5          60       RL         84.0  14260.0   Pave      IR1
# ...    ...         ...      ...          ...      ...    ...      ...
# 1455  1456          60       RL         62.0   7917.0   Pave      Reg
# 1456  1457          20       RL         85.0  13175.0   Pave      Reg
# 1457  1458          70       RL         66.0   9042.0   Pave      Reg
# 1458  1459          20       RL         68.0   9717.0   Pave      Reg
# 1459  1460          20       RL         75.0   9937.0   Pave      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# ...

# %%
X_train = df.drop("SalePrice", axis=1)
y_train = df["SalePrice"]
X_test = df1.copy()

# %%
X_test = df1

# %%
cat_cols = X_train.select_dtypes(include="object").columns

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

ct = ColumnTransformer(
    transformers=[
        (
            "ohe",
            OneHotEncoder(
                drop="first",
                handle_unknown="ignore",
                sparse_output=False
            ),
            cat_cols
        )
    ],
    remainder="passthrough"
)

# %%
X_train
# Out:
# array([[0.000e+00, 0.000e+00, 1.000e+00, ..., 0.000e+00, 2.000e+00,
#         2.008e+03],
#        [0.000e+00, 0.000e+00, 1.000e+00, ..., 0.000e+00, 5.000e+00,
#         2.007e+03],
#        [0.000e+00, 0.000e+00, 1.000e+00, ..., 0.000e+00, 9.000e+00,
#         2.008e+03],
#        ...,
#        [0.000e+00, 0.000e+00, 1.000e+00, ..., 0.000e+00, 5.000e+00,
#         2.010e+03],
#        [0.000e+00, 0.000e+00, 1.000e+00, ..., 0.000e+00, 4.000e+00,
#         2.010e+03],
#        [0.000e+00, 0.000e+00, 1.000e+00, ..., 0.000e+00, 6.000e+00,
#         2.008e+03]])

# %%
X_train = ct.fit_transform(X_train)
X_test = ct.transform(X_test)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0, 4, 14, 15, 29, 30, 38] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(

# %%
X_train
# Out:
# array([[0.000e+00, 0.000e+00, 1.000e+00, ..., 0.000e+00, 2.000e+00,
#         2.008e+03],
#        [0.000e+00, 0.000e+00, 1.000e+00, ..., 0.000e+00, 5.000e+00,
#         2.007e+03],
#        [0.000e+00, 0.000e+00, 1.000e+00, ..., 0.000e+00, 9.000e+00,
#         2.008e+03],
#        ...,
#        [0.000e+00, 0.000e+00, 1.000e+00, ..., 0.000e+00, 5.000e+00,
#         2.010e+03],
#        [0.000e+00, 0.000e+00, 1.000e+00, ..., 0.000e+00, 4.000e+00,
#         2.010e+03],
#        [0.000e+00, 0.000e+00, 1.000e+00, ..., 0.000e+00, 6.000e+00,
#         2.008e+03]])

# %%
X_test
# Out:
# array([[0.000e+00, 1.000e+00, 0.000e+00, ..., 0.000e+00, 6.000e+00,
#         2.010e+03],
#        [0.000e+00, 0.000e+00, 1.000e+00, ..., 0.000e+00, 6.000e+00,
#         2.010e+03],
#        [0.000e+00, 0.000e+00, 1.000e+00, ..., 0.000e+00, 3.000e+00,
#         2.010e+03],
#        ...,
#        [0.000e+00, 0.000e+00, 1.000e+00, ..., 0.000e+00, 9.000e+00,
#         2.006e+03],
#        [0.000e+00, 0.000e+00, 1.000e+00, ..., 0.000e+00, 7.000e+00,
#         2.006e+03],
#        [0.000e+00, 0.000e+00, 1.000e+00, ..., 0.000e+00, 1.100e+01,
#         2.006e+03]])

# %%
print(type(X_train))
print(X_train.dtype if hasattr(X_train, "dtype") else "No dtype")
# Out:
# <class 'numpy.ndarray'>
# float64

# %%
XGBRegressor(
    n_estimators=3000,
    learning_rate=0.01,
    max_depth=3,
    subsample=0.8,
    colsample_bytree=0.8,
    reg_alpha=0.1,
    reg_lambda=1,
    random_state=42
)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#              enable_categorical=True, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.01, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=3,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=3000,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
model.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=True, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.05, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=3,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=1000,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
import numpy as np

y_pred = model.predict(X_test)
y_pred = np.expm1(y_pred)

# %%
import pandas as pd

test = pd.read_csv("test.csv")

submission = pd.DataFrame({
    "Id": test["Id"],
    "SalePrice": y_pred
})

submission.to_csv("submission.csv", index=False)

# %%
y_pred.shape
# Out:
# (1459,)
